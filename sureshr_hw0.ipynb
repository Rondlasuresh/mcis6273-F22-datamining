# %% [markdown]
# \*\* Assignment 0 \*\*
#
# -   Zotero Username : Rondlasuresh
#
# -   Zotero Mail :SRondla2583@muleriders.saumag.edu
#
# # 1)List 3 things that you learned from this podcast?
#
# Here is a list of the things I discovered from the podcast:
#
# -   The rise in popularity and demand for Jupyter notebooks
# -   Jupyter is an open-source online tool used as a coding and data
#     analysis development environment.
# -   Benefits of Jupyter Notebooks over Javascript and other coding
#     languages
#
# # 2) What is your reaction to the podcast? Pick at least one point Adam brought up in the interview that you agree with and list your reason why
#
# How many people create notebooks and use them on github versus how many
# are truly intended for other people to consume them is one of the
# interesting points.
#
# In certain circumstances, people establish repositories for themselves
# that are built for various purposes and aren’t really meant for use or
# reference by others. It was the goal of Adam Analysis to determine how
# individuals were describing the projects and what keywords they were
# using. He excluded words from the keyword search such as notebooks and
# github, and the top terms he discovered were machine learning,
# Nanodegree, etc. This shows that many individuals are learning machine
# learning, data analysis, doing online tests, and hosting their outputs
# and results online. I find a lot of information to be really useful and
# educating. I concur with Adam’s analysis of the many uses of the
# notebooks.
#
# # 3) After listening to the podcast, do you think you are more interested or less interested in learning from Jupyter notebooks on Github?
#
# I found using Jupyter Notebooks on github for studying various data
# tools to be quite intriguing after listening to the episode. Github is a
# fantastic resource for learning a variety of skills because to its
# benefits including versioning and excellent documentation.
